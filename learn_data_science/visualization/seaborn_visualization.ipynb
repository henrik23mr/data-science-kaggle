# %%
import seaborn as sns

sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset('tips')

tips.keys()
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
iris = sns.load_dataset('iris')

iris.keys()
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
titanic = sns.load_dataset('titanic')

titanic.keys()
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
planets = sns.load_dataset('planets')

planets.keys()
# Out:
# Index(['method', 'number', 'orbital_period', 'mass', 'distance', 'year'], dtype='object')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x='tip', y='total_bill', data=tips)
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.scatterplot(x='tip', y='total_bill', data=tips, hue='day', size='size')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.scatterplot(x='tip', y='total_bill', data=tips, hue='sex', size='size', palette='GnBu')
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.histplot(tips['tip'], kde=True, bins=20)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(tips['tip'], kde=False, bins=20)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.distplot(tips['tip'], kde=True, bins=20)
# Out:
# <ipython-input-12-d05d16f14653>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(tips['tip'], kde=True, bins=20)
# <Axes: xlabel='tip', ylabel='Density'>

# %%
sns.barplot(x='sex', y='tip', data=tips, hue='sex', palette='YlGnBu')
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
sns.boxplot(x='day', y='tip', data=tips, hue='sex', palette='YlGnBu')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.stripplot(x='day', y='tip', data=tips, hue='sex', dodge=True, palette='RdBu')
# Out:
# <Axes: xlabel='day', ylabel='tip'>

# %%
sns.jointplot(x='tip', y='total_bill', data=tips, kind='reg', palette='YlGnBu')

# %%
sns.jointplot(x='tip', y='total_bill', data=tips, kind='scatter', hue='sex', palette='YlGnBu')

# %%
sns.lmplot(x='tip', y='total_bill', data=tips, hue='sex', palette='YlGnBu')

# %%
sns.jointplot(x='tip', y='total_bill', data=tips, kind='kde', palette='YlGnBu')

# %%
sns.jointplot(x='tip', y='total_bill', data=tips, kind='kde', shade=True, cmap='YlGnBu')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1832: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, y=self.y, **kwargs)

# %%
sns.jointplot(x='tip', y='total_bill', data=tips, kind='hex', cmap='YlGnBu')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.pairplot(titanic.select_dtypes(['number']), hue='pclass')

# %%
pair_grid = sns.pairplot(titanic.select_dtypes(['number']), hue='pclass')

pair_grid.axes[0, 0].set_facecolor('red')

# %%
tit = titanic

tit
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
tit['sex'] = tit['sex'].replace({'male': 0, 'female': 1})

tit
# Out:
#      survived  pclass  sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    0  22.0      1      0   7.2500        S   Third
# 1           1       1    1  38.0      1      0  71.2833        C   First
# 2           1       3    1  26.0      0      0   7.9250        S   Third
# 3           1       1    1  35.0      1      0  53.1000        S   First
# 4           0       3    0  35.0      0      0   8.0500        S   Third
# ..        ...     ...  ...   ...    ...    ...      ...      ...     ...
# 886         0       2    0  27.0      0      0  13.0000        S  Second
# 887         1       1    1  19.0      0      0  30.0000        S   First
# 888         0       3    1   NaN      1      2  23.4500        S   Third
# 889         1       1    0  26.0      0      0  30.0000        C   First
# 890         0       3    0  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
numeric_titanic = titanic.select_dtypes(include=['number'])
correlation_matrix = numeric_titanic.corr()

correlation_matrix
# Out:
#           survived    pclass       sex       age     sibsp     parch      fare
# survived  1.000000 -0.338481  0.543351 -0.077221 -0.035322  0.081629  0.257307
# pclass   -0.338481  1.000000 -0.131900 -0.369226  0.083081  0.018443 -0.549500
# sex       0.543351 -0.131900  1.000000 -0.093254  0.114631  0.245489  0.182333
# age      -0.077221 -0.369226 -0.093254  1.000000 -0.308247 -0.189119  0.096067
# sibsp    -0.035322  0.083081  0.114631 -0.308247  1.000000  0.414838  0.159651
# parch     0.081629  0.018443  0.245489 -0.189119  0.414838  1.000000  0.216225
# fare      0.257307 -0.549500  0.182333  0.096067  0.159651  0.216225  1.000000

# %%
sns.heatmap(numeric_titanic.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.clustermap(iris.drop('species', axis=1))

# %% [markdown]
# part 2

# %%
crash = sns.load_dataset('car_crashes')

crash.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
sns.displot(data=crash['not_distracted'], kde=True, bins=20)

# %%
sns.jointplot(data=crash, x='speeding', y='alcohol',kind='reg')

# %%
sns.jointplot(data=crash, x='speeding', y='alcohol',kind='kde', cmap='coolwarm', shade=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1832: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(x=self.x, y=self.y, **kwargs)

# %%
sns.jointplot(data=crash, x='speeding', y='alcohol',kind='hex', palette='YlGnBu')

# %%
sns.kdeplot(data=crash['alcohol'])
# Out:
# <Axes: xlabel='alcohol', ylabel='Density'>

# %%
sns.pairplot(data=crash)

# %%
tips = sns.load_dataset('tips')

tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
test_tips = tips

test_tips['sex'] = test_tips['sex'].replace({'Female': 1, 'Male': 0})

test_tips
# Out:
#      total_bill   tip sex smoker   day    time  size
# 0         16.99  1.01   1     No   Sun  Dinner     2
# 1         10.34  1.66   0     No   Sun  Dinner     3
# 2         21.01  3.50   0     No   Sun  Dinner     3
# 3         23.68  3.31   0     No   Sun  Dinner     2
# 4         24.59  3.61   1     No   Sun  Dinner     4
# ..          ...   ...  ..    ...   ...     ...   ...
# 239       29.03  5.92   0     No   Sat  Dinner     3
# 240       27.18  2.00   1    Yes   Sat  Dinner     2
# 241       22.67  2.00   0    Yes   Sat  Dinner     2
# 242       17.82  1.75   0     No   Sat  Dinner     2
# 243       18.78  3.00   1     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.pairplot(data=tips, hue='sex', palette='Blues')

# %%
sns.rugplot(data=tips['tip'])
# Out:
# <Axes: xlabel='tip'>

# %%
import matplotlib.pyplot as plt

sns.set_style('darkgrid')

sns.jointplot(data=crash, x='speeding', y='alcohol', kind='reg')

plt.figure(figsize=(8,4))

# %%
import matplotlib.pyplot as plt

sns.set_style('dark')

sns.jointplot(data=crash, x='speeding', y='alcohol', kind='reg')

plt.figure(figsize=(8,4))

# %%
import matplotlib.pyplot as plt

sns.set_style('ticks')

sns.jointplot(data=crash, x='speeding', y='alcohol', kind='reg')

plt.figure(figsize=(8,4))

# %%
import matplotlib.pyplot as plt

sns.set_style('darkgrid')

sns.set_context('paper', font_scale=1.4)

sns.jointplot(data=crash, x='speeding', y='alcohol', kind='reg')

plt.figure(figsize=(8,4))

# %%
import matplotlib.pyplot as plt

sns.set_style('darkgrid')

sns.set_context('talk', font_scale=1.4)

sns.jointplot(data=crash, x='speeding', y='alcohol', kind='reg')

plt.figure(figsize=(8,4))

# %%
import matplotlib.pyplot as plt

sns.set_style('white')

sns.set_context('paper', font_scale=1.4)

sns.jointplot(data=crash, x='speeding', y='alcohol', kind='reg')

sns.despine(left=False, bottom=True)

plt.figure(figsize=(8,4))

# %%
tips['sex'] = tips['sex'].replace({1: 'Female', 0: 'Male'})

tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import numpy as np

sns.barplot(data=tips, x='sex', y='total_bill', hue='sex', palette='coolwarm', estimator=np.median)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(data=tips, x='sex', y='total_bill', hue='sex', palette='coolwarm', estimator=np.cov)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.countplot(x='sex', data=tips, color='blue')
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.violinplot(data=tips, x='day', y='total_bill', hue='sex')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>
