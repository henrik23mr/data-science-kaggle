# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd

file_path = '/content/gdrive/My Drive/pokemon_data.csv'

df = pd.read_csv(file_path)

df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
df.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df['Type 1'].value_counts().plot(kind='pie', autopct='%1.1f%%', cmap='tab20c', figsize=(8,6))
# Out:
# <Axes: ylabel='count'>

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df['Total'] = df['HP'] + df['Attack'] + df['Defense']

# %%
df['Total'].plot(kind='hist', figsize=(8,6))
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Total'].plot(kind='box', vert=False, figsize=(8,6))
# Out:
# <Axes: >

# %%
df['Legendary'].value_counts().plot(kind='pie', autopct='%1.1f%%', cmap='Set3', figsize=(8, 6))
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# ### **Basic filtering**

# %%
 attack_greater = df.loc[df['Attack'] > 170]

 attack_greater
# Out:
#        #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 232  214  HeracrossMega Heracross      Bug  Fighting   80     185      115
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 429  386       DeoxysAttack Forme  Psychic       NaN   50     180       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 163      154      100    130           1       True    396
# 232       40      105     75           2      False    380
# 424      150       90     90           3       True    440
# 426      180      100    115           3       True    385
# 429      180       20    150           3       True    250

# %%
len(attack_greater)
# Out:
# 5

# %%
df.query('Attack > 170')
# Out:
#        #                     Name   Type 1    Type 2   HP  Attack  Defense  \
# 163  150      MewtwoMega Mewtwo X  Psychic  Fighting  106     190      100
# 232  214  HeracrossMega Heracross      Bug  Fighting   80     185      115
# 424  383    GroudonPrimal Groudon   Ground      Fire  100     180      160
# 426  384    RayquazaMega Rayquaza   Dragon    Flying  105     180      100
# 429  386       DeoxysAttack Forme  Psychic       NaN   50     180       20
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 163      154      100    130           1       True    396
# 232       40      105     75           2      False    380
# 424      150       90     90           3       True    440
# 426      180      100    115           3       True    385
# 429      180       20    150           3       True    250

# %%
import seaborn as sns

sns.boxplot(data=df, x='Speed')
# Out:
# <Axes: xlabel='Speed'>

# %%
df.loc[df['Speed'] <= 10]
# Out:
#        #       Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 230  213    Shuckle     Bug   Rock   20      10      230       10      230
# 359  328   Trapinch  Ground    NaN   45     100       45       45       45
# 486  438     Bonsly    Rock    NaN   50      80       95       10       45
# 495  446   Munchlax  Normal    NaN  135      85       40       40       85
# 658  597  Ferroseed   Grass  Steel   44      50       91       24       86
#
#      Speed  Generation  Legendary  Total
# 230      5           2      False    260
# 359     10           3      False    190
# 486     10           4      False    225
# 495      5           4      False    260
# 658     10           5      False    185

# %%
df.query('Speed <= 10')
# Out:
#        #       Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 230  213    Shuckle     Bug   Rock   20      10      230       10      230
# 359  328   Trapinch  Ground    NaN   45     100       45       45       45
# 486  438     Bonsly    Rock    NaN   50      80       95       10       45
# 495  446   Munchlax  Normal    NaN  135      85       40       40       85
# 658  597  Ferroseed   Grass  Steel   44      50       91       24       86
#
#      Speed  Generation  Legendary  Total
# 230      5           2      False    260
# 359     10           3      False    190
# 486     10           4      False    225
# 495      5           4      False    260
# 658     10           5      False    185

# %%
df['Speed'] <= 10

count_value_speed = [x for x in df['Speed'] if x <= 10]

count_value_speed
# Out:
# [5, 10, 10, 5, 10]

# %%
values = [0, 0]

for x in df['Speed'] <= 10:
  if x:
    values[0] += 1
  else:
    values[1] += 1

values
# Out:
# [5, 795]

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Total'],
#       dtype='object')

# %%
(df['Sp. Def'] <= 25).sum()
# Out:
# 18

# %%
df['Legendary'].sum() # counting bool values

df.loc[df['Legendary'] == True]
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 156  144             Articuno       Ice    Flying   90      85      100
# 157  145               Zapdos  Electric    Flying   90      90       85
# 158  146              Moltres      Fire    Flying   90     100       90
# 162  150               Mewtwo   Psychic       NaN  106     110       90
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting  106     190      100
# ..   ...                  ...       ...       ...  ...     ...      ...
# 795  719              Diancie      Rock     Fairy   50     100      150
# 796  719  DiancieMega Diancie      Rock     Fairy   50     160      110
# 797  720  HoopaHoopa Confined   Psychic     Ghost   80     110       60
# 798  720   HoopaHoopa Unbound   Psychic      Dark   80     160       60
# 799  721            Volcanion      Fire     Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# ...

# %%
df.loc[df['Legendary']]
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 156  144             Articuno       Ice    Flying   90      85      100
# 157  145               Zapdos  Electric    Flying   90      90       85
# 158  146              Moltres      Fire    Flying   90     100       90
# 162  150               Mewtwo   Psychic       NaN  106     110       90
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting  106     190      100
# ..   ...                  ...       ...       ...  ...     ...      ...
# 795  719              Diancie      Rock     Fairy   50     100      150
# 796  719  DiancieMega Diancie      Rock     Fairy   50     160      110
# 797  720  HoopaHoopa Confined   Psychic     Ghost   80     110       60
# 798  720   HoopaHoopa Unbound   Psychic      Dark   80     160       60
# 799  721            Volcanion      Fire     Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# ...

# %%
ax = sns.scatterplot(data=df, x='Defense', y='Attack')

# %%
df.sort_values(by=['Defense', 'Attack'], ascending=[False, True]).head()
# Out:
#        #                 Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 230  213              Shuckle    Bug    Rock  20      10      230       10
# 224  208  SteelixMega Steelix  Steel  Ground  75     125      230       55
# 333  306    AggronMega Aggron  Steel     NaN  70     140      230       60
# 223  208              Steelix  Steel  Ground  75      85      200       55
# 414  377             Regirock   Rock     NaN  80     100      200       50
#
#      Sp. Def  Speed  Generation  Legendary  Total
# 230      230      5           2      False    260
# 224       95     30           2      False    430
# 333       80     50           3      False    440
# 223       65     30           2      False    360
# 414      100     50           3       True    380

# %%
(
  (df['Type 1'] == 'Fire') &
  (df['Type 2'] == 'Flying')
 ).sum()
# Out:
# 6

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Total'],
#       dtype='object')

# %%
type1_set = set()
for name in df['Type 1']:
  if name not in type1_set:
    type1_set.add(name)

type1_set
# Out:
# {'Bug',
#  'Dark',
#  'Dragon',
#  'Electric',
#  'Fairy',
#  'Fighting',
#  'Fire',
#  'Flying',
#  'Ghost',
#  'Grass',
#  'Ground',
#  'Ice',
#  'Normal',
#  'Poison',
#  'Psychic',
#  'Rock',
#  'Steel',
#  'Water'}

# %%
from collections import Counter

item_count = Counter(df['Type 1'])

item_count
# Out:
# Counter({'Grass': 70,
#          'Fire': 52,
#          'Water': 112,
#          'Bug': 69,
#          'Normal': 98,
#          'Poison': 28,
#          'Electric': 44,
#          'Ground': 32,
#          'Fairy': 17,
#          'Fighting': 27,
#          'Psychic': 57,
#          'Rock': 44,
#          'Ghost': 32,
#          'Ice': 24,
#          'Dragon': 32,
#          'Dark': 31,
#          'Steel': 27,
#          'Flying': 4})

# %%
df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison')]
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison   45      49       49       65
# 1      2                Ivysaur  Grass  Poison   60      62       63       80
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 48    43                 Oddish  Grass  Poison   45      50       55       75
# 49    44                  Gloom  Grass  Poison   60      65       70       85
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 75    69             Bellsprout  Grass  Poison   50      75       35       70
# 76    70             Weepinbell  Grass  Poison   65      90       50       85
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 344  315                Roselia  Grass  Poison   50      60       45      100
# ...

# %%
len(df.loc[(df['Type 1'] == 'Grass') | (df['Type 2'] == 'Poison')])
# Out:
# 89

# %%
new_df = (df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison') & (df['HP'] >= 70)])

new_df
# Out:
#        #                   Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 2      3               Venusaur  Grass  Poison   80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 50    45              Vileplume  Grass  Poison   75      80       85      110
# 77    71             Victreebel  Grass  Poison   80     105       65      100
# 652  591              Amoonguss  Grass  Poison  114      85       70       85
#
#      Sp. Def  Speed  Generation  Legendary  Total
# 2        100     80           1      False    245
# 3        120     80           1      False    303
# 50        90     50           1      False    240
# 77        70     70           1      False    250
# 652       80     30           5      False    269

# %%
new_df = new_df.reset_index()
new_df
# Out:
#    index    #                   Name Type 1  Type 2   HP  Attack  Defense  \
# 0      2    3               Venusaur  Grass  Poison   80      82       83
# 1      3    3  VenusaurMega Venusaur  Grass  Poison   80     100      123
# 2     50   45              Vileplume  Grass  Poison   75      80       85
# 3     77   71             Victreebel  Grass  Poison   80     105       65
# 4    652  591              Amoonguss  Grass  Poison  114      85       70
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0      100      100     80           1      False    245
# 1      122      120     80           1      False    303
# 2      110       90     50           1      False    240
# 3      100       70     70           1      False    250
# 4       85       80     30           5      False    269

# %%
new_df['Name'].str.contains("Mega")
# Out:
# 0    False
# 1     True
# 2    False
# 3    False
# 4    False
# Name: Name, dtype: bool

# %%
new_df.loc[new_df['Name'].str.contains("Mega")]
# Out:
#    index  #                   Name Type 1  Type 2  HP  Attack  Defense  \
# 1      3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 1      122      120     80           1      False    303

# %%
new_df.loc[~new_df['Name'].str.contains("Mega")] #negate
# Out:
#    index    #        Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  \
# 0      2    3    Venusaur  Grass  Poison   80      82       83      100
# 2     50   45   Vileplume  Grass  Poison   75      80       85      110
# 3     77   71  Victreebel  Grass  Poison   80     105       65      100
# 4    652  591   Amoonguss  Grass  Poison  114      85       70       85
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0      100     80           1      False    245
# 2       90     50           1      False    240
# 3       70     70           1      False    250
# 4       80     30           5      False    269

# %%
import re

df.loc[df['Type 1'].str.contains('fire|grass|Steel', flags=re.I, regex=True)]
# Out:
#        #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur  Grass  Poison  45      49       49       65
# 1      2                Ivysaur  Grass  Poison  60      62       63       80
# 2      3               Venusaur  Grass  Poison  80      82       83      100
# 3      3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4      4             Charmander   Fire     NaN  39      52       43       60
# ..   ...                    ...    ...     ...  ..     ...      ...      ...
# 749  680               Doublade  Steel   Ghost  59     110      150       45
# 750  681   AegislashBlade Forme  Steel   Ghost  60     150       50      150
# 751  681  AegislashShield Forme  Steel   Ghost  60      50      150       50
# 777  707                 Klefki  Steel   Fairy  57      80       91       80
# 799  721              Volcanion   Fire   Water  80     110      120      130
#
# ...

# %%
df.loc[df['Name'].str.startswith('Ch')]
# Out:
#        #                       Name   Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander     Fire       NaN   39      52       43
# 5      5                 Charmeleon     Fire       NaN   58      64       58
# 6      6                  Charizard     Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X     Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y     Fire    Flying   78     104       78
# 121  113                    Chansey   Normal       NaN  250       5        5
# 166  152                  Chikorita    Grass       NaN   45      49       65
# 184  170                   Chinchou    Water  Electric   75      38       38
# 391  358                   Chimecho  Psychic       NaN   65      50       70
# 435  390                   Chimchar     Fire       NaN   44      58       44
# 467  420                    Cherubi    Grass       NaN   45      35       45
# ...

# %%
df.loc[df['Name'].str.contains('pi[a-z]*')]
# Out:
#        #        Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 13    10    Caterpie      Bug     NaN   45      30       35       20       20
# 42    37      Vulpix     Fire     NaN   38      41       40       50       65
# 76    70  Weepinbell    Grass  Poison   65      90       50       85       45
# 84    78    Rapidash     Fire     NaN   65     100       70       80       80
# 181  167    Spinarak      Bug  Poison   40      60       40       40       40
# 189  175      Togepi    Fairy     NaN   35      20       65       40       65
# 202  187      Hoppip    Grass  Flying   35      35       40       35       55
# 266  247     Pupitar     Rock  Ground   70      84       70       65       70
# 345  316      Gulpin   Poison     NaN   70      43       53       43       53
# 357  326     Grumpig  Psychic     NaN   80      45       65       90      110
# 358  327      Spinda   Normal     NaN   60      60       60       60       60
# ...

# %%
df.loc[df['Name'].str.contains('^pi[a-z]*', flags=re.I, regex=True)]
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 20    16               Pidgey    Normal    Flying   40      45       40
# 21    17            Pidgeotto    Normal    Flying   63      60       55
# 22    18              Pidgeot    Normal    Flying   83      80       75
# 23    18  PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25              Pikachu  Electric       NaN   35      55       40
# 136  127               Pinsir       Bug       NaN   65     125      100
# 137  127    PinsirMega Pinsir       Bug    Flying   65     155      120
# 186  172                Pichu  Electric       NaN   20      40       15
# 219  204               Pineco       Bug       NaN   50      65       90
# 239  221            Piloswine       Ice    Ground  100     100       80
# 438  393               Piplup     Water       NaN   53      51       53
# 558  499              Pignite      Fire  Fighting   90      93       55
# ...

# %%
df.loc[df['Name'].str.startswith('Pi')]
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 20    16               Pidgey    Normal    Flying   40      45       40
# 21    17            Pidgeotto    Normal    Flying   63      60       55
# 22    18              Pidgeot    Normal    Flying   83      80       75
# 23    18  PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 30    25              Pikachu  Electric       NaN   35      55       40
# 136  127               Pinsir       Bug       NaN   65     125      100
# 137  127    PinsirMega Pinsir       Bug    Flying   65     155      120
# 186  172                Pichu  Electric       NaN   20      40       15
# 219  204               Pineco       Bug       NaN   50      65       90
# 239  221            Piloswine       Ice    Ground  100     100       80
# 438  393               Piplup     Water       NaN   53      51       53
# 558  499              Pignite      Fire  Fighting   90      93       55
# ...

# %%
pi_names = [x for x in df['Name'] if x.startswith('Pi')]

pi_names[:4]
# Out:
# ['Pidgey', 'Pidgeotto', 'Pidgeot', 'PidgeotMega Pidgeot']

# %%
new_df.loc[new_df['Type 1'] == 'Grass', 'Type 1'] = 'Grasser'

new_df
# Out:
#    index    #                   Name   Type 1  Type 2   HP  Attack  Defense  \
# 0      2    3               Venusaur  Grasser  Poison   80      82       83
# 1      3    3  VenusaurMega Venusaur  Grasser  Poison   80     100      123
# 2     50   45              Vileplume  Grasser  Poison   75      80       85
# 3     77   71             Victreebel  Grasser  Poison   80     105       65
# 4    652  591              Amoonguss  Grasser  Poison  114      85       70
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0      100      100     80           1      False    245
# 1      122      120     80           1      False    303
# 2      110       90     50           1      False    240
# 3      100       70     70           1      False    250
# 4       85       80     30           5      False    269

# %%
new_df.loc[new_df['Type 1'] == 'Grasser', 'Type 1'] = 'Grass'

new_df
# Out:
#    index    #                   Name Type 1  Type 2   HP  Attack  Defense  \
# 0      2    3               Venusaur  Grass  Poison   80      82       83
# 1      3    3  VenusaurMega Venusaur  Grass  Poison   80     100      123
# 2     50   45              Vileplume  Grass  Poison   75      80       85
# 3     77   71             Victreebel  Grass  Poison   80     105       65
# 4    652  591              Amoonguss  Grass  Poison  114      85       70
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0      100      100     80           1      False    245
# 1      122      120     80           1      False    303
# 2      110       90     50           1      False    240
# 3      100       70     70           1      False    250
# 4       85       80     30           5      False    269

# %%
new_df.loc[new_df['Type 2'] == 'Poison', 'Type 2'] = 'Poisonous'

new_df
# Out:
#    index    #                   Name Type 1     Type 2   HP  Attack  Defense  \
# 0      2    3               Venusaur  Grass  Poisonous   80      82       83
# 1      3    3  VenusaurMega Venusaur  Grass  Poisonous   80     100      123
# 2     50   45              Vileplume  Grass  Poisonous   75      80       85
# 3     77   71             Victreebel  Grass  Poisonous   80     105       65
# 4    652  591              Amoonguss  Grass  Poisonous  114      85       70
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0      100      100     80           1      False    245
# 1      122      120     80           1      False    303
# 2      110       90     50           1      False    240
# 3      100       70     70           1      False    250
# 4       85       80     30           5      False    269

# %%
new_df.loc[new_df['Total'] < 500, ['Generation', 'Legendary']] = 'Test_value'


new_df
# Out:
#    index    #                   Name Type 1     Type 2   HP  Attack  Defense  \
# 0      2    3               Venusaur  Grass  Poisonous   80      82       83
# 1      3    3  VenusaurMega Venusaur  Grass  Poisonous   80     100      123
# 2     50   45              Vileplume  Grass  Poisonous   75      80       85
# 3     77   71             Victreebel  Grass  Poisonous   80     105       65
# 4    652  591              Amoonguss  Grass  Poisonous  114      85       70
#
#    Sp. Atk  Sp. Def  Speed  Generation   Legendary  Total
# 0      100      100     80  Test_value  Test_value    245
# 1      122      120     80  Test_value  Test_value    303
# 2      110       90     50  Test_value  Test_value    240
# 3      100       70     70  Test_value  Test_value    250
# 4       85       80     30  Test_value  Test_value    269
